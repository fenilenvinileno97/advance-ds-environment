# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ##### Import libraries

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import modules.utils.paths as path
import modules.visualization.visualize as visual
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import re
from IPython.display import display, Markdown

# %%
data_dir = path.make_dir_function('.')

# %%
renewable_dir = list(data_dir('..', '..', 'Datasets', 'renewable').resolve().glob("*.csv"))
names_renewable_dir = [re.search(r"\w+\-.*", str(x))[0].replace("-", "_") for x in renewable_dir]

# %%
display(Markdown(f"### **1. Dataset:** {names_renewable_dir[0]}"))
share_electricity_wind_df = pd.read_csv(renewable_dir[0])
share_electricity_wind_df.tail()
# Out:
# ### **1. Dataset:** share_electricity_wind.csv
#         Entity Code  Year  Wind (% electricity)
# 6374  Zimbabwe  ZWE  2016                   0.0
# 6375  Zimbabwe  ZWE  2017                   0.0
# 6376  Zimbabwe  ZWE  2018                   0.0
# 6377  Zimbabwe  ZWE  2019                   0.0
# 6378  Zimbabwe  ZWE  2020                   0.0

# %%
visual.null_values_proportion(share_electricity_wind_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **2. Dataset:** {names_renewable_dir[1]}"))
wind_share_energy_df = pd.read_csv(renewable_dir[1])
wind_share_energy_df.tail()
# Out:
# ### **2. Dataset:** wind_share_energy.csv
#      Entity      Code  Year  Wind (% sub energy)
# 4830  World  OWID_WRL  2016                1.579
# 4831  World  OWID_WRL  2017                1.827
# 4832  World  OWID_WRL  2018                1.972
# 4833  World  OWID_WRL  2019                2.174
# 4834  World  OWID_WRL  2020                2.539

# %%
visual.null_values_proportion(wind_share_energy_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **3. Dataset:** {names_renewable_dir[2]}"))
biofuel_production_df = pd.read_csv(renewable_dir[2])
biofuel_production_df.tail()
# Out:
# ### **3. Dataset:** biofuel_production.csv
#      Entity      Code  Year  Biofuels Production - TWh - Total
# 1080  World  OWID_WRL  2016                         927.775210
# 1081  World  OWID_WRL  2017                         969.005102
# 1082  World  OWID_WRL  2018                        1067.869413
# 1083  World  OWID_WRL  2019                        1110.499302
# 1084  World  OWID_WRL  2020                        1043.003238

# %%
visual.null_values_proportion(biofuel_production_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **4. Dataset:** {names_renewable_dir[3]}"))
installed_solar_PV_capacity_df = pd.read_csv(renewable_dir[3])
installed_solar_PV_capacity_df.tail()
# Out:
# ### **4. Dataset:** installed_solar_PV_capacity.csv
#      Entity      Code  Year  Solar Capacity
# 1515  World  OWID_WRL  2016      291.295309
# 1516  World  OWID_WRL  2017      384.451503
# 1517  World  OWID_WRL  2018      482.915904
# 1518  World  OWID_WRL  2019      580.760214
# 1519  World  OWID_WRL  2020      707.495000

# %%
visual.null_values_proportion(installed_solar_PV_capacity_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **5. Dataset:** {names_renewable_dir[4]}"))
installed_geothermal_capacity_df = pd.read_csv(renewable_dir[4])
installed_geothermal_capacity_df.tail()
# Out:
# ### **5. Dataset:** installed_geothermal_capacity.csv
#     Entity      Code  Year  Geothermal Capacity
# 753  World  OWID_WRL  2016            12121.594
# 754  World  OWID_WRL  2017            12680.665
# 755  World  OWID_WRL  2018            13244.865
# 756  World  OWID_WRL  2019            13911.665
# 757  World  OWID_WRL  2020            14075.000

# %%
visual.null_values_proportion(installed_geothermal_capacity_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **6. Dataset:** {names_renewable_dir[5]}"))
modern_renewable_prod_df = pd.read_csv(renewable_dir[5])
modern_renewable_prod_df.tail()
# Out:
# ### **6. Dataset:** modern_renewable_prod.csv
#         Entity Code  Year  Electricity from wind (TWh)  \
# 7990  Zimbabwe  ZWE  2016                          0.0
# 7991  Zimbabwe  ZWE  2017                          0.0
# 7992  Zimbabwe  ZWE  2018                          0.0
# 7993  Zimbabwe  ZWE  2019                          0.0
# 7994  Zimbabwe  ZWE  2020                          0.0
#
#       Electricity from hydro (TWh)  Electricity from solar (TWh)  \
# 7990                          2.95                          0.01
# 7991                          3.93                          0.01
# 7992                          5.00                          0.01
# 7993                          7.26                          0.01
# 7994                          7.26                          0.01
#
#       Electricity from other renewables including bioenergy (TWh)
# 7990                                               0.36
# 7991                                               0.32
# ...

# %%
visual.null_values_proportion(modern_renewable_prod_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **7. Dataset:** {names_renewable_dir[6]}"))
solar_share_energy_df = pd.read_csv(renewable_dir[6])
solar_share_energy_df.tail()
# Out:
# ### **7. Dataset:** solar_share_energy.csv
#      Entity      Code  Year  Solar (% sub energy)
# 4830  World  OWID_WRL  2016                 0.539
# 4831  World  OWID_WRL  2017                 0.715
# 4832  World  OWID_WRL  2018                 0.896
# 4833  World  OWID_WRL  2019                 1.085
# 4834  World  OWID_WRL  2020                 1.365

# %%
visual.null_values_proportion(solar_share_energy_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **8. Dataset:** {names_renewable_dir[7]}"))
share_electricity_renewables_df = pd.read_csv(renewable_dir[7])
share_electricity_renewables_df.tail()
# Out:
# ### **8. Dataset:** share_electricity_renewables.csv
#         Entity Code  Year  Renewables (% electricity)
# 6369  Zimbabwe  ZWE  2016                      48.680
# 6370  Zimbabwe  ZWE  2017                      58.276
# 6371  Zimbabwe  ZWE  2018                      59.146
# 6372  Zimbabwe  ZWE  2019                      67.639
# 6373  Zimbabwe  ZWE  2020                      67.639

# %%
visual.null_values_proportion(share_electricity_renewables_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **9. Dataset:** {names_renewable_dir[8]}"))
hydro_share_energy_df = pd.read_csv(renewable_dir[8])
hydro_share_energy_df.tail()
# Out:
# ### **9. Dataset:** hydro_share_energy.csv
#      Entity      Code  Year  Hydro (% sub energy)
# 4830  World  OWID_WRL  2016                 6.594
# 4831  World  OWID_WRL  2017                 6.515
# 4832  World  OWID_WRL  2018                 6.486
# 4833  World  OWID_WRL  2019                 6.481
# 4834  World  OWID_WRL  2020                 6.856

# %%
visual.null_values_proportion(hydro_share_energy_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **10. Dataset:** {names_renewable_dir[9]}"))
share_electricity_hydro_df = pd.read_csv(renewable_dir[9])
share_electricity_hydro_df.tail()
# Out:
# ### **10. Dataset:** share_electricity_hydro.csv
#         Entity Code  Year  Hydro (% electricity)
# 6374  Zimbabwe  ZWE  2016                 43.255
# 6375  Zimbabwe  ZWE  2017                 53.762
# 6376  Zimbabwe  ZWE  2018                 54.765
# 6377  Zimbabwe  ZWE  2019                 64.191
# 6378  Zimbabwe  ZWE  2020                 64.191

# %%
visual.null_values_proportion(share_electricity_hydro_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **11. Dataset:** {names_renewable_dir[10]}"))
renewable_share_energy_df = pd.read_csv(renewable_dir[10])
renewable_share_energy_df.tail()
# Out:
# ### **11. Dataset:** renewable_share_energy.csv
#      Entity      Code  Year  Renewables (% sub energy)
# 4830  World  OWID_WRL  2016                     10.239
# 4831  World  OWID_WRL  2017                     10.618
# 4832  World  OWID_WRL  2018                     10.978
# 4833  World  OWID_WRL  2019                     11.437
# 4834  World  OWID_WRL  2020                     12.553

# %%
visual.null_values_proportion(renewable_share_energy_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **12. Dataset:** {names_renewable_dir[11]}"))
share_electricity_solar_df = pd.read_csv(renewable_dir[11])
share_electricity_solar_df.tail()
# Out:
# ### **12. Dataset:** share_electricity_solar.csv
#         Entity Code  Year  Solar (% electricity)
# 6375  Zimbabwe  ZWE  2016                  0.147
# 6376  Zimbabwe  ZWE  2017                  0.137
# 6377  Zimbabwe  ZWE  2018                  0.110
# 6378  Zimbabwe  ZWE  2019                  0.088
# 6379  Zimbabwe  ZWE  2020                  0.088

# %%
visual.null_values_proportion(share_electricity_solar_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **13. Dataset:** {names_renewable_dir[12]}"))
solar_energy_consumption_df = pd.read_csv(renewable_dir[12])
solar_energy_consumption_df.tail()
# Out:
# ### **13. Dataset:** solar_energy_consumption.csv
#         Entity Code  Year  Electricity from solar (TWh)
# 7990  Zimbabwe  ZWE  2016                          0.01
# 7991  Zimbabwe  ZWE  2017                          0.01
# 7992  Zimbabwe  ZWE  2018                          0.01
# 7993  Zimbabwe  ZWE  2019                          0.01
# 7994  Zimbabwe  ZWE  2020                          0.01

# %%
visual.null_values_proportion(solar_energy_consumption_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **14. Dataset:** {names_renewable_dir[13]}"))
modern_renewable_energy_consumption_df = pd.read_csv(renewable_dir[13])
modern_renewable_energy_consumption_df.tail()
# Out:
# ### **14. Dataset:** modern_renewable_energy_consumption.csv
#      Entity      Code  Year  Wind Generation - TWh  Solar Generation - TWh  \
# 4998  World  OWID_WRL  2016             962.227395              328.385208
# 4999  World  OWID_WRL  2017            1140.310949              446.054164
# 5000  World  OWID_WRL  2018            1269.520536              576.951248
# 5001  World  OWID_WRL  2019            1418.170046              707.918495
# 5002  World  OWID_WRL  2020            1591.213512              855.724690
#
#       Geo Biomass Other - TWh  Hydro Generation - TWh
# 4998               560.681082             4018.671591
# 4999               593.790980             4066.718275
# 5000               632.173911             4176.687496
# 5001               663.134292             4227.883280
# 5002               700.068651             4296.802045

# %%
visual.null_values_proportion(modern_renewable_energy_consumption_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **15. Dataset:** {names_renewable_dir[14]}"))
hydropower_consumption_df = pd.read_csv(renewable_dir[14])
hydropower_consumption_df.tail()
# Out:
# ### **15. Dataset:** hydropower_consumption.csv
#         Entity Code  Year  Electricity from hydro (TWh)
# 7989  Zimbabwe  ZWE  2016                          2.95
# 7990  Zimbabwe  ZWE  2017                          3.93
# 7991  Zimbabwe  ZWE  2018                          5.00
# 7992  Zimbabwe  ZWE  2019                          7.26
# 7993  Zimbabwe  ZWE  2020                          7.26

# %%
visual.null_values_proportion(hydropower_consumption_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **16. Dataset:** {names_renewable_dir[15]}"))
wind_generation_df = pd.read_csv(renewable_dir[15])
wind_generation_df.tail()
# Out:
# ### **16. Dataset:** wind_generation.csv
#         Entity Code  Year  Electricity from wind (TWh)
# 7989  Zimbabwe  ZWE  2016                          0.0
# 7990  Zimbabwe  ZWE  2017                          0.0
# 7991  Zimbabwe  ZWE  2018                          0.0
# 7992  Zimbabwe  ZWE  2019                          0.0
# 7993  Zimbabwe  ZWE  2020                          0.0

# %%
visual.null_values_proportion(wind_generation_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
display(Markdown(f"### **17. Dataset:** {names_renewable_dir[16]}"))
cumulative_installed_wind_energy_capacity_gw_df = pd.read_csv(renewable_dir[16])
cumulative_installed_wind_energy_capacity_gw_df.tail()
# Out:
# ### **17. Dataset:** cumulative_installed_wind_energy_capacity_gigawatts.csv
#      Entity      Code  Year  Wind Capacity
# 1398  World  OWID_WRL  2016     466.861116
# 1399  World  OWID_WRL  2017     514.374030
# 1400  World  OWID_WRL  2018     563.829025
# 1401  World  OWID_WRL  2019     622.248925
# 1402  World  OWID_WRL  2020     733.276000

# %%
visual.null_values_proportion(cumulative_installed_wind_energy_capacity_gw_df)
# Out:
# /home/fenilenvinileno97/anaconda3/envs/final_project/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
